# %% [markdown]
# # Lightsheet microscopy data exploration

# %%
from ome_arrow import OMEArrow
import pathlib

img_file = "data/PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif"

if not pathlib.Path(img_file).exists():
    raise FileNotFoundError(f"Image file not found: {img_file}")

oa_imge = OMEArrow()
oa_imge
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 img_file = "data/PetaKit5PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif"
#       6 if not pathlib.Path(img_file).exists():
# ----> 7     raise FileNotFoundError(f"Image file not found: {img_file}")
#       9 oa_imge = OMEArrow()
#      10 oa_imge
#
# FileNotFoundError: Image file not found: data/PetaKit5PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif

# %%
# !pwd
# Out:
# /Users/buntend/Documents/work/demo-lightsheet-data-proc/src/demo-lightsheet-data-proc

# %%
import tifffile

tfff_img = tifffile.imread("data/PetaKit5PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif")

tfff_img.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zw/l3g4vq6508g98qkt05z6hb_m0000gp/T/ipykernel_47791/2950417525.py in ?()
#       1 import tifffile
#       2
# ----> 3 tfff_img = tifffile.imread("data/PetaKit5PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif")
#       4
#       5 tfff_img.shape
#
# ~/Documents/work/demo-lightsheet-data-proc/.venv/lib/python3.12/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, superres, out, out_inplace, _multifile, _useframes, **kwargs)
#    1183         ):
#    1184             files = files[0]
#    1185
#    1186         if isinstance(files, str) or not isinstance(files, Sequence):
# -> 1187             with TiffFile(
#    1188                 files,
#    1189                 mode=mode,
#    1190                 name=name,
#
# ~/Documents/work/demo-lightsheet-data-proc/.venv/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size, omexml, superres, _multifile, _useframes, _parent, **is_flags)
#    4292                 raise ValueError(msg)
#    4293             self._omexml = omexml
#    4294             self.is_ome = True
#    4295
# -> 4296         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4297         self._fh = fh
#    4298         self._multifile = True if _multifile is None else bool(_multifile)
#    4299         self._files = {fh.name: self}
#
# ~/Documents/work/demo-lightsheet-data-proc/.venv/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size)
#   13595         self._offset = -1 if offset is None else offset
#   13596         self._size = -1 if size is None else size
#   13597         self._close = True
#   13598         self._lock = NullContext()
# > 13599         self.open()
#   13600         assert self._fh is not None
#
# ~/Documents/work/demo-lightsheet-data-proc/.venv/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self)
#   13615                 msg = f'invalid mode {self._mode}'
#   13616                 raise ValueError(msg)
#   13617             self._file = os.path.realpath(self._file)
#   13618             self._dir, self._name = os.path.split(self._file)
# > 13619             self._fh = open(  # noqa: SIM115
#   13620                 self._file, self._mode, encoding=None
#   13621             )
#   13622             self._close = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/buntend/Documents/work/demo-lightsheet-data-proc/src/demo-lightsheet-data-proc/data/PetaKit5PetaKit5D_demo_cell_image_dataset/Scan_Iter_0000_0000_CamA_ch0_CAM1_stack0000_488nm_0000000msec_0106060251msecAbs_000x_003y_000z_0000t.tif'
